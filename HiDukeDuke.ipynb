# %% [markdown]
# Project: HiDukeDuke

# %%
import os
from urllib.parse import urlparse

os.chdir(path=r"C:\Users\iz\Documents\Python\File, Folder Manipulation\URL_Parse")
#put 'r' before the path to convert a 'normal' string to a 'raw' string

# open the text file and read its contents to a string
s = ""
with open("links.txt", "r") as text_file:
    s = text_file.read()
# display the text
# print(s)

# Extract the URLs using the urlparse() function
urls = [urlparse(url).geturl() for url in s.split() if urlparse(url).scheme]
# display the extracted URLs
print(urls)
# Out:
# ['https://doc-0c-c4-mymaps.googleusercontent.com/untrusted/hostedimage/llv4tggra4rj0ipdqpfipm5pic/9dfvrcb623njo9sn83q8l2q7ic/1670941467000/7Ah1YFWy-PObs8mpfA-MHtEvKNiH5vzK/10541753519325588412/5AKgB-9kbIuEtJQF9Gp6gaWYI3WiDM03ISjwmN3vG6Wz1D8WygovYbDSidhnmO_PGPwAQ7pj9pWr4t-9nS8HTHh13D_El_wGVke0jCFe05Hbt2KhWT70oLVQkvKU44nGGOTymA7dV7TiHiVWPN7--iS9JeoxB5aZboPgJefv3yjqjYj_h8VZK7cQjzNIcmn0ytp3JBuI?session=0&fife', 'https://doc-0c-c4-mymaps.googleusercontent.com/untrusted/hostedimage/llv4tggra4rj0ipdqpfipm5pic/66couknd8u79l8n7l5o418opns/1670941467000/7Ah1YFWy-PObs8mpfA-MHtEvKNiH5vzK/10541753519325588412/5AKgB-9liIHW-O45NObALiz0Fjq7hyWugDFnSmzLPH6quQX7h2k4xBbX5Pq5gpkakwh3mvwbr_egaliq9LCy2kwNqQhdxvmT3ERsIrRywN2rM7thUfzT89ZMwbbgeHcbd8sAwEbGJ9UD1yivN11jYnfK8t101beyHJW8OESJ-AUBQwliyGHSlgFHerIaPHVArdHGwVkk?session=0&fife', 'https://doc-00-c4-mymaps.googleusercontent.com/untrusted/hostedimage/llv4tggra4rj0ipdqpfipm5pic/qn2h8pk1goo1vgrchk011c61h0/1670941467000/7Ah1YFWy-PObs8mpfA-MHtEvKNiH5vzK/105417
# ...

# %%
"""
HiDukeDuke Code
"""
old_name = "this_is_sparta.aac"
new_name = old_name
print(new_name)
# Out:
# this_is_sparta.aac

# %%
"""
Getting the dates from the module 'datetime' 
"""
from datetime import datetime
print(datetime.today().strftime("%y%m%d, w/o dashes"))        #%Y displays YYyy, %y displays yy
print(datetime.today().strftime("%y-%m-%d, w/ dashes"))
# Out:
# 220905, w/o dashes
# 22-09-05, w/ dashes

# %%
from IPython.core.display import os
os.rename()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-e0d5754f5270> in <module>
#       1 from IPython.core.display import os
# ----> 2 os.rename()
#
# TypeError: rename() missing required argument 'src' (pos 1)

# %%
import os
from datetime import datetime


os.chdir(path=r"C:\Users\iz\Documents\Python\File, Folder Manipulation")
#put 'r' before the path to convert a 'normal' string to a 'raw' string

old_name = "220905lekoleko.txt"
os.rename(old_name, datetime.today().strftime("%y%m%d") + "_" + "lekoleko.txt")
print("hope this worked..")
# Out:
# hope this worked..

# %%
import os
from datetime import datetime

foruda = r"C:\Users\iz\Documents\Python\File, Folder Manipulation"
#put 'r' before the path to convert a 'normal' string to a 'raw' string

for file_name in os.listdir(foruda):
    # Construct old file name
    source = foruda + file_name

    # Adding the count to the new file name and extension
    destination = foruda + "sales_" + str(count) + ".txt"

    # Renaming the file
    os.rename(source, destination)
print('All Files Renamed')

old_name = "220905lekoleko.txt"
os.rename(old_name, datetime.today().strftime("%y%m%d") + "_" + "lekoleko.txt")
print("hope this worked..")

# %%
import os
from datetime import datetime
from urllib.request import AbstractDigestAuthHandler

foruda = r"C:\Users\iz\Documents\Python\HiDukeDuke\\"
# the "\\" at the end is of extreme importance, otherwise it'll syntax error in your face

# iterate all files from a directory
for file_name in os.listdir(foruda):
    # Construct old file name
    source = foruda + file_name

    # Adding the current date to the new file name and extension
    destination = foruda + datetime.today().strftime("%y%m%d") + "_" + file_name
        # this is for date and time
    # destination = foruda + "ANYTHING" + " - " + file_name 
        # this is for adding pre-/suffixes

    # Renaming the file
    os.rename(source, destination)
print('All Files Renamed')

print('New Names are')
# verify the result
res = os.listdir(foruda)
print(res)
# Out:
# All Files Renamed
# New Names are
# ['220920_packet sw vs circuit sw.docx']
